# %% [markdown]
# <a href="https://colab.research.google.com/github/Yangel300/Sistemas_Embebidos_2025-2/blob/main/SuperTonic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/supertone-inc/supertonic.git
# Out:
# Cloning into 'supertonic'...
# remote: Enumerating objects: 171, done.
# remote: Counting objects: 100% (171/171), done.
# remote: Compressing objects: 100% (93/93), done.
# remote: Total 171 (delta 76), reused 171 (delta 76), pack-reused 0 (from 0)
# Receiving objects: 100% (171/171), 313.05 KiB | 3.68 MiB/s, done.
# Resolving deltas: 100% (76/76), done.

# %%
# !git clone https://huggingface.co/Supertone/supertonic assets
# Out:
# Cloning into 'assets'...
# remote: Enumerating objects: 55, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 55 (delta 20), reused 0 (delta 0), pack-reused 3 (from 1)
# Unpacking objects: 100% (55/55), 530.46 KiB | 5.53 MiB/s, done.
# Filtering content: 100% (4/4), 251.30 MiB | 84.29 MiB/s, done.
